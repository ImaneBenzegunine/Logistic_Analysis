# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from geopy.distance import geodesic  # For calculating distance
import os,sys

# %% [markdown]
# Load your dataset

# %%
scripts_path = os.path.abspath(os.path.join(os.getcwd(), '../Scripts'))
sys.path.append(scripts_path)

# %%
from paths import PATH_CLEAN_CSV

# %%
data= pd.read_csv(PATH_CLEAN_CSV)

# %%
data
# Out:
#        Unnamed: 0       Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 0               0  ialx566343618         37           4.9       22.745049
# 1               1  akqg208421122         34           4.5       12.913041
# 2               2  njpu434582536         23           4.4       12.914264
# 3               3  rjto796129700         38           4.7       11.003669
# 4               4  zguw716275638         32           4.6       12.972793
# ...           ...            ...        ...           ...             ...
# 40104       43733  gcxb277393192         35           4.2       23.371292
# 40105       43734  jlxf819993117         30           4.8       26.902328
# 40106       43736  xnek760674819         30           4.9       13.022394
# 40107       43737  cynl434665991         20           4.7       11.001753
# 40108       43738  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 0            75.892471      22.765049       75.912471  2022-03-19   11:30:00
# 1            77.683237      13.043041       77.813237  2022-03-25   19:45:00
# 2            77.678400      12.924264       77.688400  2022-03-19   08:30:00
# 3            76.976494      11.053669       77.026494  2022-04-05   18:00:00
# 4            80.249982      13.012793       80.289982  2022-03-26   13:30:00
# ...                ...            ...             ...         ...        ...
# 40104        85.327872      23.481292       85.437872  2022-03-08   21:45:00
# 40105        75.794257      26.912328       75.804257  2022-03-24   11:35:00
# 40106        80.242439      13.052394       80.272439  2022-03-11   23:50:00
# 40107        76.986241      11.041753       77.026241  2022-03-07   13:35:00
# 40108        85.325731      23.431058       85.405731  2022-03-02   17:10:00
#
#       Pickup_Time     Weather  Traffic      Vehicle            Area  \
# 0        11:45:00       Sunny    High   motorcycle           Urban
# 1        19:50:00      Stormy     Jam      scooter   Metropolitian
# 2        08:45:00  Sandstorms     Low   motorcycle           Urban
# 3        18:10:00       Sunny  Medium   motorcycle   Metropolitian
# 4        13:45:00      Cloudy    High      scooter   Metropolitian
# ...           ...         ...      ...          ...             ...
# 40104    21:55:00       Windy     Jam   motorcycle   Metropolitian
# 40105    11:45:00       Windy    High   motorcycle   Metropolitian
# 40106    00:05:00      Cloudy     Low      scooter   Metropolitian
# 40107    13:40:00      Cloudy    High   motorcycle   Metropolitian
# 40108    17:15:00         Fog  Medium      scooter   Metropolitian
#
#        Delivery_Time     Category
# 0                120     Clothing
# 1                165  Electronics
# 2                130       Sports
# 3                105    Cosmetics
# 4                150         Toys
# ...              ...          ...
# 40104            165       Sports
# 40105            160         Home
# 40106             80         Home
# 40107            130      Kitchen
# 40108            180    Cosmetics
#
# [40109 rows x 17 columns]

# %% [markdown]
# ### 1. Data Preprocessing

# %%
data=data.drop('Unnamed: 0',axis=1)

# %%
data
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 0      ialx566343618         37           4.9       22.745049
# 1      akqg208421122         34           4.5       12.913041
# 2      njpu434582536         23           4.4       12.914264
# 3      rjto796129700         38           4.7       11.003669
# 4      zguw716275638         32           4.6       12.972793
# ...              ...        ...           ...             ...
# 40104  gcxb277393192         35           4.2       23.371292
# 40105  jlxf819993117         30           4.8       26.902328
# 40106  xnek760674819         30           4.9       13.022394
# 40107  cynl434665991         20           4.7       11.001753
# 40108  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 0            75.892471      22.765049       75.912471  2022-03-19   11:30:00
# 1            77.683237      13.043041       77.813237  2022-03-25   19:45:00
# 2            77.678400      12.924264       77.688400  2022-03-19   08:30:00
# 3            76.976494      11.053669       77.026494  2022-04-05   18:00:00
# 4            80.249982      13.012793       80.289982  2022-03-26   13:30:00
# ...                ...            ...             ...         ...        ...
# 40104        85.327872      23.481292       85.437872  2022-03-08   21:45:00
# 40105        75.794257      26.912328       75.804257  2022-03-24   11:35:00
# 40106        80.242439      13.052394       80.272439  2022-03-11   23:50:00
# 40107        76.986241      11.041753       77.026241  2022-03-07   13:35:00
# 40108        85.325731      23.431058       85.405731  2022-03-02   17:10:00
#
#       Pickup_Time     Weather  Traffic      Vehicle            Area  \
# 0        11:45:00       Sunny    High   motorcycle           Urban
# 1        19:50:00      Stormy     Jam      scooter   Metropolitian
# 2        08:45:00  Sandstorms     Low   motorcycle           Urban
# 3        18:10:00       Sunny  Medium   motorcycle   Metropolitian
# 4        13:45:00      Cloudy    High      scooter   Metropolitian
# ...           ...         ...      ...          ...             ...
# 40104    21:55:00       Windy     Jam   motorcycle   Metropolitian
# 40105    11:45:00       Windy    High   motorcycle   Metropolitian
# 40106    00:05:00      Cloudy     Low      scooter   Metropolitian
# 40107    13:40:00      Cloudy    High   motorcycle   Metropolitian
# 40108    17:15:00         Fog  Medium      scooter   Metropolitian
#
#        Delivery_Time     Category
# 0                120     Clothing
# 1                165  Electronics
# 2                130       Sports
# 3                105    Cosmetics
# 4                150         Toys
# ...              ...          ...
# 40104            165       Sports
# 40105            160         Home
# 40106             80         Home
# 40107            130      Kitchen
# 40108            180    Cosmetics
#
# [40109 rows x 16 columns]

# %% [markdown]
# Convert date and time columns to datetime

# %%
data['Order_Date'] = pd.to_datetime(data['Order_Date'])
data['Order_Time'] = pd.to_datetime(data['Order_Time'], format='%H:%M:%S').dt.time
data['Pickup_Time'] = pd.to_datetime(data['Pickup_Time'], format='%H:%M:%S').dt.time

# %% [markdown]
# Calculate distance between store and drop location

# %%
data['Distance'] = data.apply(lambda row: geodesic((row['Store_Latitude'], row['Store_Longitude']), 
                                              (row['Drop_Latitude'], row['Drop_Longitude'])).km, axis=1)

# %% [markdown]
# # Drop unnecessary columns

# %%
data = data.drop(['Order_ID', 'Store_Latitude', 'Store_Longitude', 'Drop_Latitude', 'Drop_Longitude', 
              'Order_Date', 'Order_Time', 'Pickup_Time'], axis=1)

# %%
data=data.drop(['Category'],axis=1)

# %%
data.head()
# Out:
#    Agent_Age  Agent_Rating     Weather  Traffic      Vehicle            Area  \
# 0         37           4.9       Sunny    High   motorcycle           Urban
# 1         34           4.5      Stormy     Jam      scooter   Metropolitian
# 2         23           4.4  Sandstorms     Low   motorcycle           Urban
# 3         38           4.7       Sunny  Medium   motorcycle   Metropolitian
# 4         32           4.6      Cloudy    High      scooter   Metropolitian
#
#    Delivery_Time   Distance
# 0            120   3.020737
# 1            165  20.143737
# 2            130   1.549693
# 3            105   7.774497
# 4            150   6.197898

# %% [markdown]
# One-hot encode categorical variables

# %%
data = pd.get_dummies(data, columns=['Weather', 'Traffic', 'Vehicle', 'Area'], drop_first=True)

# %%
data
# Out:
#        Agent_Age  Agent_Rating  Delivery_Time   Distance  Weather_Fog  \
# 0             37           4.9            120   3.020737        False
# 1             34           4.5            165  20.143737        False
# 2             23           4.4            130   1.549693        False
# 3             38           4.7            105   7.774497        False
# 4             32           4.6            150   6.197898        False
# ...          ...           ...            ...        ...          ...
# 40104         35           4.2            165  16.576800        False
# 40105         30           4.8            160   1.488112        False
# 40106         30           4.9             80   4.648024        False
# 40107         20           4.7            130   6.219668        False
# 40108         23           4.9            180  12.057294         True
#
#        Weather_Sandstorms  Weather_Stormy  Weather_Sunny  Weather_Windy  \
# 0                   False           False           True          False
# 1                   False            True          False          False
# 2                    True           False          False          False
# 3                   False           False           True          False
# 4                   False           False          False          False
# ...                   ...             ...            ...            ...
# 40104               False           False          False           True
# 40105               False           False          False           True
# 40106               False           False          False          False
# 40107               False           False          False          False
# 40108               False           False          False          False
#
#        Traffic_Jam   Traffic_Low   Traffic_Medium   Vehicle_scooter   \
# 0             False         False            False             False
# 1              True         False            False              True
# 2             False          True            False             False
# 3             False         False             True             False
# 4             False         False            False              True
# ...             ...           ...              ...               ...
# 40104          True         False            False             False
# 40105         False         False            False             False
# 40106         False          True            False              True
# 40107         False         False            False             False
# 40108         False         False             True              True
#
#        Vehicle_van  Area_Other  Area_Semi-Urban   Area_Urban
# 0            False       False             False         True
# 1            False       False             False        False
# 2            False       False             False         True
# 3            False       False             False        False
# 4            False       False             False        False
# ...            ...         ...               ...          ...
# 40104        False       False             False        False
# 40105        False       False             False        False
# 40106        False       False             False        False
# 40107        False       False             False        False
# 40108        False       False             False        False
#
# [40109 rows x 17 columns]

# %%
X = data.drop('Delivery_Time', axis=1)
y = data['Delivery_Time']

# %% [markdown]
# split data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict on test data
y_pred = model.predict(X_test)

# Calculate evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Absolute Error: 31.320381919969122
# Mean Squared Error: 1757.672073480632
# R-squared: 0.34863379854246734

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, X, y, cv=5, scoring='r2')
print(f"Cross-Validation R²: {scores.mean()}")
# Out:
# Cross-Validation R²: 0.3508979752998462

# %%
from sklearn.preprocessing import PolynomialFeatures

# Create polynomial features
poly = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly.fit_transform(X)

# Split and train the model
X_train_poly, X_test_poly, y_train, y_test = train_test_split(X_poly, y, test_size=0.2, random_state=42)
model.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
# Create polynomial features
poly = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly.fit_transform(X)  # Transform the entire feature set

# Split the data into training and testing sets
X_train_poly, X_test_poly, y_train, y_test = train_test_split(X_poly, y, test_size=0.2, random_state=42)

# Train the model on polynomial features
model = LinearRegression()
model.fit(X_train_poly, y_train)

# Predict on the polynomial-transformed test data
y_pred = model.predict(X_test_poly)  # Use X_test_poly, not X_test

# Calculate evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Absolute Error: 30.424831224914808
# Mean Squared Error: 1693.7906619202836
# R-squared: 0.36931626884961244
